# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv('second_dataset.csv')

# %%
data
# Out:
#       Customer ID   Age  Gender Item Purchased     Category  \
# 0               1   NaN    Male         Blouse     Clothing
# 1               2   NaN    Male        Sweater     Clothing
# 2               3   NaN    Male          Jeans     Clothing
# 3               4   NaN    Male        Sandals     Footwear
# 4               5   NaN    Male         Blouse     Clothing
# ...           ...   ...     ...            ...          ...
# 3895         3896  40.0  Female         Hoodie     Clothing
# 3896         3897  52.0  Female       Backpack  Accessories
# 3897         3898  46.0  Female           Belt  Accessories
# 3898         3899  44.0  Female          Shoes     Footwear
# 3899         3900  52.0  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                       NaN       Kentucky    L       Gray  Winter
# 1                       NaN          Maine    L     Maroon  Winter
# ...

# %%
data.head()
# Out:
#    Customer ID  Age Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1  NaN   Male         Blouse  Clothing                    NaN
# 1            2  NaN   Male        Sweater  Clothing                    NaN
# 2            3  NaN   Male          Jeans  Clothing                    NaN
# 3            4  NaN   Male        Sandals  Footwear                   90.0
# 4            5  NaN   Male         Blouse  Clothing                    NaN
#
#         Location Size      Color  Season  Review Rating Subscription Status  \
# 0       Kentucky    L       Gray  Winter            NaN                 yep
# 1          Maine    L     Maroon  Winter            NaN                 Yes
# 2  Massachusetts    S     Maroon  Spring            NaN                 Yes
# 3   Rhode Island    M     Maroon  Spring            NaN                 Yes
# 4         Oregon    M  Turquoise  Spring            NaN                  Yo
#
# ...

# %%
data.shape
# Out:
# (3900, 19)

# %%
data.dtypes
# Out:
# Customer ID                   int64
# Age                         float64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)       float64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Customer ID               3900 non-null   int64
#  1   Age                       3269 non-null   float64
#  2   Gender                    3900 non-null   object
#  3   Item Purchased            3900 non-null   object
#  4   Category                  3900 non-null   object
#  5   Purchase Amount (USD)     3285 non-null   float64
#  6   Location                  3900 non-null   object
#  7   Size                      3900 non-null   object
#  8   Color                     3900 non-null   object
#  9   Season                    3900 non-null   object
#  10  Review Rating             3246 non-null   float64
#  11  Subscription Status       3900 non-null   object
#  12  Payment Method            3900 non-null   object
# ...

# %%
data.describe()
# Out:
#        Customer ID          Age  Purchase Amount (USD)  Review Rating  \
# count  3900.000000  3269.000000            3285.000000    3246.000000
# mean   1950.500000    43.973998              59.863014       3.744239
# std    1125.977353    15.216359              23.673623       0.719448
# min       1.000000    18.000000              20.000000       2.500000
# 25%     975.750000    31.000000              39.000000       3.100000
# 50%    1950.500000    44.000000              60.000000       3.750000
# 75%    2925.250000    57.000000              81.000000       4.400000
# max    3900.000000    70.000000             100.000000       5.000000
#
#        Previous Purchases
# count         3900.000000
# mean            25.351538
# std             14.447125
# min              1.000000
# 25%             13.000000
# 50%             25.000000
# 75%             38.000000
# max             50.000000

# %%
data.isnull().sum()
# Out:
# Customer ID                   0
# Age                         631
# Gender                        0
# Item Purchased                0
# Category                      0
# Purchase Amount (USD)       615
# Location                      0
# Size                          0
# Color                         0
# Season                        0
# Review Rating               654
# Subscription Status           0
# Payment Method                0
# Shipping Type                 0
# Discount Applied              0
# Promo Code Used               0
# Previous Purchases            0
# Preferred Payment Method      0
# Frequency of Purchases        0
# dtype: int64

# %%
data.dropna()
# Out:
#       Customer ID   Age  Gender Item Purchased     Category  \
# 87             88  52.0    Male          Shoes     Footwear
# 109           110  58.0    Male        T-shirt     Clothing
# 115           116  53.0    Male          Skirt     Clothing
# 131           132  28.0    Male          Skirt     Clothing
# 180           181  51.0    Male        Sandals     Footwear
# ...           ...   ...     ...            ...          ...
# 3894         3895  66.0  Female          Skirt     Clothing
# 3895         3896  40.0  Female         Hoodie     Clothing
# 3896         3897  52.0  Female       Backpack  Accessories
# 3897         3898  46.0  Female           Belt  Accessories
# 3898         3899  44.0  Female          Shoes     Footwear
#
#       Purchase Amount (USD)      Location Size      Color  Season  \
# 87                     53.0          Ohio    M      Green    Fall
# 109                    85.0       Alabama    M     Violet  Spring
# ...

# %%
data.dropna(axis=1)
# Out:
#       Customer ID  Gender Item Purchased     Category       Location Size  \
# 0               1    Male         Blouse     Clothing       Kentucky    L
# 1               2    Male        Sweater     Clothing          Maine    L
# 2               3    Male          Jeans     Clothing  Massachusetts    S
# 3               4    Male        Sandals     Footwear   Rhode Island    M
# 4               5    Male         Blouse     Clothing         Oregon    M
# ...           ...     ...            ...          ...            ...  ...
# 3895         3896  Female         Hoodie     Clothing       Virginia    L
# 3896         3897  Female       Backpack  Accessories           Iowa    L
# 3897         3898  Female           Belt  Accessories     New Jersey    L
# 3898         3899  Female          Shoes     Footwear      Minnesota    S
# 3899         3900  Female        Handbag  Accessories     California    M
#
#           Color  Season Subscription Status Payment Method   Shipping Type  \
# ...

# %%
data.dropna(how = 'all')
# Out:
#       Customer ID   Age  Gender Item Purchased     Category  \
# 0               1   NaN    Male         Blouse     Clothing
# 1               2   NaN    Male        Sweater     Clothing
# 2               3   NaN    Male          Jeans     Clothing
# 3               4   NaN    Male        Sandals     Footwear
# 4               5   NaN    Male         Blouse     Clothing
# ...           ...   ...     ...            ...          ...
# 3895         3896  40.0  Female         Hoodie     Clothing
# 3896         3897  52.0  Female       Backpack  Accessories
# 3897         3898  46.0  Female           Belt  Accessories
# 3898         3899  44.0  Female          Shoes     Footwear
# 3899         3900  52.0  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                       NaN       Kentucky    L       Gray  Winter
# 1                       NaN          Maine    L     Maroon  Winter
# ...

# %%
# works same as data.dropna

# %%
data.dropna(how = 'any')
# Out:
#       Customer ID   Age  Gender Item Purchased     Category  \
# 87             88  52.0    Male          Shoes     Footwear
# 109           110  58.0    Male        T-shirt     Clothing
# 115           116  53.0    Male          Skirt     Clothing
# 131           132  28.0    Male          Skirt     Clothing
# 180           181  51.0    Male        Sandals     Footwear
# ...           ...   ...     ...            ...          ...
# 3894         3895  66.0  Female          Skirt     Clothing
# 3895         3896  40.0  Female         Hoodie     Clothing
# 3896         3897  52.0  Female       Backpack  Accessories
# 3897         3898  46.0  Female           Belt  Accessories
# 3898         3899  44.0  Female          Shoes     Footwear
#
#       Purchase Amount (USD)      Location Size      Color  Season  \
# 87                     53.0          Ohio    M      Green    Fall
# 109                    85.0       Alabama    M     Violet  Spring
# ...

# %%
data.dropna(thresh=17)
# Out:
#       Customer ID   Age  Gender Item Purchased     Category  \
# 3               4   NaN    Male        Sandals     Footwear
# 5               6   NaN    Male       Sneakers     Footwear
# 6               7   NaN    Male          Shirt     Clothing
# 7               8   NaN    Male         Shorts     Clothing
# 9              10  57.0    Male        Handbag  Accessories
# ...           ...   ...     ...            ...          ...
# 3895         3896  40.0  Female         Hoodie     Clothing
# 3896         3897  52.0  Female       Backpack  Accessories
# 3897         3898  46.0  Female           Belt  Accessories
# 3898         3899  44.0  Female          Shoes     Footwear
# 3899         3900  52.0  Female        Handbag  Accessories
#
#       Purchase Amount (USD)      Location Size      Color  Season  \
# 3                      90.0  Rhode Island    M     Maroon  Spring
# 5                       NaN       Wyoming    M      White  Summer
# ...

# %%
data['Customer ID']
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 3895    3896
# 3896    3897
# 3897    3898
# 3898    3899
# 3899    3900
# Name: Customer ID, Length: 3900, dtype: int64

# %%
data['Customer ID'].unique()
# Out:
# array([   1,    2,    3, ..., 3898, 3899, 3900])

# %%
data['Age']
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 3895    40.0
# 3896    52.0
# 3897    46.0
# 3898    44.0
# 3899    52.0
# Name: Age, Length: 3900, dtype: float64

# %%
data['Age'].isnull()
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 3895    False
# 3896    False
# 3897    False
# 3898    False
# 3899    False
# Name: Age, Length: 3900, dtype: bool

# %%
data['Age'].fillna('not recorded', inplace=True)

# %%
data
# Out:
#       Customer ID           Age  Gender Item Purchased     Category  \
# 0               1  not recorded    Male         Blouse     Clothing
# 1               2  not recorded    Male        Sweater     Clothing
# 2               3  not recorded    Male          Jeans     Clothing
# 3               4  not recorded    Male        Sandals     Footwear
# 4               5  not recorded    Male         Blouse     Clothing
# ...           ...           ...     ...            ...          ...
# 3895         3896          40.0  Female         Hoodie     Clothing
# 3896         3897          52.0  Female       Backpack  Accessories
# 3897         3898          46.0  Female           Belt  Accessories
# 3898         3899          44.0  Female          Shoes     Footwear
# 3899         3900          52.0  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                       NaN       Kentucky    L       Gray  Winter
# ...

# %%
data['Age'].value_counts()
# Out:
# Age
# not recorded    631
# 57.0             76
# 41.0             76
# 49.0             74
# 69.0             72
# 25.0             71
# 42.0             70
# 32.0             69
# 31.0             69
# 62.0             69
# 43.0             68
# 54.0             67
# 19.0             67
# 68.0             66
# 28.0             66
# 59.0             66
# 29.0             66
# 52.0             65
# 27.0             65
# 35.0             65
# 37.0             65
# 23.0             64
# 58.0             64
# 46.0             64
# 63.0             63
# 30.0             62
# 51.0             61
# 18.0             61
# 40.0             61
# 56.0             61
# 36.0             60
# 66.0             60
# 22.0             60
# 47.0             60
# 64.0             59
# 55.0             59
# 65.0             58
# 39.0             58
# 21.0             57
# 34.0             57
# 26.0             57
# 45.0             56
# 60.0             55
# 61.0             55
# 48.0             55
# ...

# %%
data['Purchase Amount (USD)'].fillna('not recorded', inplace=True)

# %%
data[['Customer ID', 'Purchase Amount (USD)']]
# Out:
#       Customer ID Purchase Amount (USD)
# 0               1          not recorded
# 1               2          not recorded
# 2               3          not recorded
# 3               4                  90.0
# 4               5          not recorded
# ...           ...                   ...
# 3895         3896                  28.0
# 3896         3897                  49.0
# 3897         3898                  33.0
# 3898         3899                  77.0
# 3899         3900          not recorded
#
# [3900 rows x 2 columns]

# %%
data['Review Rating'].fillna('not rated', inplace=True)

# %%
data[['Customer ID', 'Review Rating']]
# Out:
#       Customer ID Review Rating
# 0               1     not rated
# 1               2     not rated
# 2               3     not rated
# 3               4     not rated
# 4               5     not rated
# ...           ...           ...
# 3895         3896           4.2
# 3896         3897           4.5
# 3897         3898           2.9
# 3898         3899           3.8
# 3899         3900           3.1
#
# [3900 rows x 2 columns]

# %%
data[['Customer ID','Subscription Status','Discount Applied','Promo Code Used']]
# Out:
#       Customer ID Subscription Status Discount Applied Promo Code Used
# 0               1                 yep           Indeed               y
# 1               2                 Yes              Yes              Yo
# 2               3                 Yes              Yes             Yes
# 3               4                 Yes           Indeed              Yo
# 4               5                  Yo              Yes             Yes
# ...           ...                 ...              ...             ...
# 3895         3896                  No               No             Nah
# 3896         3897                ille               No              No
# 3897         3898                  No                n              No
# 3898         3899                   N            Nakko              No
# 3899         3900                  No               No            Nope
#
# [3900 rows x 4 columns]

# %%
data['Subscription Status']
# Out:
# 0        yep
# 1        Yes
# 2        Yes
# 3        Yes
# 4         Yo
#         ...
# 3895      No
# 3896    ille
# 3897      No
# 3898       N
# 3899      No
# Name: Subscription Status, Length: 3900, dtype: object

# %%
replacement_dict = {
    'Yes': 'Yes',
    'No': 'No',
    'Haan': 'Yes',
    'ille': 'No',
    'Haanji': 'Yes',
    'indeed': 'Yes',
    'Y': 'Yes',
    'y':'Yes',
    'Yo':'Yes',
    'Of course':'Yes',
    'TRUE':'Yes',
    'yep':'Yes',
    'Naaji':'No',
    'N':'No',
    'n':'No',
    'FALSE':'No',
    'Nope':'No',
    'Nah':'No',
    'Nakko':'No',
    
    
   
}


data['Subscription Status'] = data['Subscription Status'].replace(replacement_dict)

# %%
data['Subscription Status']
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 3895     No
# 3896     No
# 3897     No
# 3898     No
# 3899     No
# Name: Subscription Status, Length: 3900, dtype: object

# %%
replacement_dict = {
    'Yes': 'Yes',
    'No': 'No',
    'Haan': 'Yes',
    'ille': 'No',
    'Haanji': 'Yes',
    'indeed': 'Yes',
    'Y': 'Yes',
    'y':'Yes',
    'Yo':'Yes',
    'Of course':'Yes',
    'TRUE':'Yes',
    'yep':'Yes',
    'Naaji':'No',
    'N':'No',
    'n':'No',
    'FALSE':'No',
    'Nope':'No',
    'Nah':'No',
    'Nakko':'No',
    'Indeed': 'Yes',
    
    
   
}


data['Discount Applied'] = data['Discount Applied'].replace(replacement_dict)

# %%
data['Discount Applied']
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 3895     No
# 3896     No
# 3897     No
# 3898     No
# 3899     No
# Name: Discount Applied, Length: 3900, dtype: object

# %%
replacement_dict = {
    'Yes': 'Yes',
    'No': 'No',
    'Haan': 'Yes',
    'ille': 'No',
    'Haanji': 'Yes',
    'indeed': 'Yes',
    'Y': 'Yes',
    'y':'Yes',
    'Yo':'Yes',
    'Of course':'Yes',
    'TRUE':'Yes',
    'yep':'Yes',
    'Naaji':'No',
    'N':'No',
    'n':'No',
    'FALSE':'No',
    'Nope':'No',
    'Nah':'No',
    'Nakko':'No',
    'Indeed': 'Yes',
    
    
   
}


data['Promo Code Used'] = data['Promo Code Used'].replace(replacement_dict)

# %%
data['Promo Code Used']
# Out:
# 0       Yes
# 1       Yes
# 2       Yes
# 3       Yes
# 4       Yes
#        ...
# 3895     No
# 3896     No
# 3897     No
# 3898     No
# 3899     No
# Name: Promo Code Used, Length: 3900, dtype: object

# %%
a = data['Age']

# %%
plt.hist(a, bins=62)
plt.xlabel('Age')
plt.ylabel('Age_counts')
plt.title('Age Distribution')
plt.show()

# %%
plt.hist(data['Purchase Amount (USD)'], bins=62, edgecolor='k', alpha=0.7)


plt.xlabel('Purchase Amount (USD)')
plt.ylabel('Count')
plt.title('Purchase Amount Distribution Histogram')


plt.show()

# %%
plt.hist(data['Previous Purchases'], bins=62, edgecolor='k', alpha=0.7)


plt.xlabel('Number of Previous Purchases')
plt.ylabel('Count')
plt.title('Number of Previous Purchases Distribution Histogram')


plt.show()

# %%
rating_counts = data['Review Rating'].value_counts().sort_index()
unique_ratings = rating_counts.index
plt.scatter(unique_ratings, rating_counts, s=50, c='b', marker='o')
plt.xlabel('Review Rating')
plt.ylabel('Count')
plt.title('Review Rating and Review Rating Counts')
# Out:
# Text(0.5, 1.0, 'Review Rating and Review Rating Counts')
